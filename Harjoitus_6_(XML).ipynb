# %% [markdown]
# # XML-tehtävät

# %% [markdown]
# #### Tehtävä 1. Lisää tarvittavat kirjastot (xml ja pandas).

# %%
import xml.etree.ElementTree as e
import pandas as pd

# %% [markdown]
# #### Tehtävä 2. Tallenna alapuolella esitetty xml-rakenne merkkijonona muuttujaan. Lisäksi lataa toiseen muuttujaan sisältö tiedostosta *users_first.xml*.

# %%
merkkijono = "<?xml version='1.0' encoding='UTF-8'?><records><record type='customer'><name>Lawrence Burke</name><phone>(815) 571-8746</phone><email>vulputate.lacus@elitfermentum.net</email><address><streetaddress>P.O. Box 478, 5254 Mi St.</streetaddress><country>Mexico</country><postalZip>22044</postalZip></address></record><record type='employee'><name>Angela Hinton</name><phone>(997) 412-6965</phone><email>elit.dictum@egestas.net</email><address><streetaddress>696-4409 Nunc Rd.</streetaddress><country>Germany</country><postalZip>661217</postalZip></address></record><record type='customer'><name>Whitney Flowers</name><phone>1-573-471-9738</phone><email>consectetuer.adipiscing.elit@ridiculusmus.ca</email><address><streetaddress>6978 Et, Av.</streetaddress><country>Indonesia</country><postalZip>28164</postalZip></address></record><record type='customer'><name>Darius Burt</name><phone>1-675-212-4934</phone><email>sociis.natoque@ut.org</email><address><streetaddress>7705 Ut Street</streetaddress><country>Indonesia</country><postalZip>94783-300</postalZip></address></record><record type='customer'><name>Solomon Blair</name><phone></phone><email>pede.suspendisse.dui@commodoat.edu</email><address><streetaddress>Ap #877-8946 Sociosqu Street</streetaddress><country>Germany</country><postalZip>113513</postalZip></address></record></records>"

# %%
tree = e.parse("users_first.xml")
root = tree.getroot()

# %% [markdown]
# #### Tehtävä 3. Muodosta molempien muuttujien sisällöistä listat C1 ja C2, joihin tallennetaan xml-datan sisällöt dictionary-tyyppisinä objekteina. HUOM: record-tasolla esitetyt attribuutit tulee ottaa mukaan objekteihin ja address-tunnisteen alla olevat tunnisteet tulee tuoda ylemmälle tasolle käyttäjän muiden ominaisuuksien kanssa!
#
# #### Alapuolella on esitetty malli, jossa ensimmäisen objektin rakenne on esitetty:
#
# [{'type': 'customer', 'name': 'Morgan Sykes', 'phone': '1-183-546-6564', 'email': 'lorem.auctor@vulputatemauris.net', 'streetaddress': '2594 Tellus St.', 'country': 'Russian Federation', 'postalZip': '584585'},...]

# %%
juuri = e.ElementTree(e.fromstring(merkkijono))

C1 = []

for i in juuri.getroot():
    person_obj = {}
    person_obj["type"] = i.attrib["type"]
    for j in i:
        if j.tag != "record":
            if j.tag == "address":
                for k in j:
                    person_obj[k.tag] = k.text
            else:
                person_obj[j.tag] = j.text
    C1.append(person_obj)
    
C1
# Out:
# [{'type': 'customer',
#   'name': 'Lawrence Burke',
#   'phone': '(815) 571-8746',
#   'email': 'vulputate.lacus@elitfermentum.net',
#   'streetaddress': 'P.O. Box 478, 5254 Mi St.',
#   'country': 'Mexico',
#   'postalZip': '22044'},
#  {'type': 'employee',
#   'name': 'Angela Hinton',
#   'phone': '(997) 412-6965',
#   'email': 'elit.dictum@egestas.net',
#   'streetaddress': '696-4409 Nunc Rd.',
#   'country': 'Germany',
#   'postalZip': '661217'},
#  {'type': 'customer',
#   'name': 'Whitney Flowers',
#   'phone': '1-573-471-9738',
#   'email': 'consectetuer.adipiscing.elit@ridiculusmus.ca',
#   'streetaddress': '6978 Et, Av.',
#   'country': 'Indonesia',
#   'postalZip': '28164'},
#  {'type': 'customer',
#   'name': 'Darius Burt',
#   'phone': '1-675-212-4934',
#   'email': 'sociis.natoque@ut.org',
#   'streetaddress': '7705 Ut Street',
#   'country': 'Indonesia',
#   'postalZip': '94783-300'},
#  {'type': 'customer',
#   'name': 'Solomon Blair',
#   'phone': None,
#   'email': 'pede.suspendisse.dui@commodoat.edu',
#   'streetaddress': 'Ap #877-8946 Sociosqu Street',
#   'country': 'Germany',
#   'postalZip': '113513'}]

# %%
C2 = []

for i in root:
    person_obj = {}
    person_obj["type"] = i.attrib["type"]
    for j in i:
        if j.tag == "address":
            address_obj = {}
            for k in j:
                person_obj[k.tag] = k.text
            person_obj["address"] = address_obj
        elif j.tag != "record":
            person_obj[j.tag] = j.text
    C2.append(person_obj)
    
C2
# Out:
# [{'type': 'customer',
#   'name': 'Morgan Sykes',
#   'phone': '1-183-546-6564',
#   'email': 'lorem.auctor@vulputatemauris.net',
#   'streetaddress': '2594 Tellus St.',
#   'country': 'Russian Federation',
#   'postalZip': '584585',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Zia Stafford',
#   'phone': '(621) 483-5714',
#   'email': 'ornare.fusce@felisdonec.co.uk',
#   'streetaddress': 'Ap #419-5905 Nibh Rd.',
#   'country': 'Netherlands',
#   'postalZip': '7308',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Cooper Ramirez',
#   'phone': '(716) 895-3353',
#   'email': 'suspendisse@consectetueradipiscingelit.edu',
#   'streetaddress': '667-4582 Mollis Ave',
#   'country': 'India',
#   'postalZip': '43714',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Richard Armstrong',
#   'phone': '(450) 317-2624',
#   'email': 'lacinia.mattis@urna.org',
#   'streetaddress': 'Ap #120-495 Ut, Road',
#   'country': 'Russian Federation',
#   'postalZip': '53415',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Flavia Delaney',
#   'phone': None,
#   'email': 'rutrum.lorem.ac@inmagna.org',
#   'streetaddress': '870-3073 Et, Av.',
#   'country': 'Austria',
#   'postalZip': '03247',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Branden Henderson',
#   'phone': '1-314-584-1088',
#   'email': 'iaculis@felisnullatempor.ca',
#   'streetaddress': 'P.O. Box 961, 9477 Gravida Avenue',
#   'country': 'Pakistan',
#   'postalZip': '50217',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Hector Kirkland',
#   'phone': '(325) 535-9750',
#   'email': 'elit@orcilacus.org',
#   'streetaddress': '541-4061 Ultricies Ave',
#   'country': 'United Kingdom',
#   'postalZip': '3865',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Luke Hooper',
#   'phone': None,
#   'email': 'vitae.sodales@vitaesodales.ca',
#   'streetaddress': 'Ap #385-5179 Luctus, Road',
#   'country': 'Germany',
#   'postalZip': '3660',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Moses Dejesus',
#   'phone': '1-337-767-2455',
#   'email': 'pede@donecdignissim.org',
#   'streetaddress': 'Ap #639-9807 Phasellus St.',
#   'country': 'Germany',
#   'postalZip': '903866',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Finn Pena',
#   'phone': '1-746-189-1226',
#   'email': 'et.euismod.et@ac.ca',
#   'streetaddress': 'Ap #668-4837 Nec Road',
#   'country': 'Netherlands',
#   'postalZip': '32910',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Lester Espinoza',
#   'phone': '1-378-721-6318',
#   'email': 'vel.nisl.quisque@ad.org',
#   'streetaddress': '4395 Elit, St.',
#   'country': 'Chile',
#   'postalZip': '07740-64584',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Nelle Stafford',
#   'phone': '1-246-844-4648',
#   'email': 'ligula@posuere.com',
#   'streetaddress': 'Ap #640-4104 Maecenas St.',
#   'country': 'Chile',
#   'postalZip': '800308',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Amber Casey',
#   'phone': None,
#   'email': 'diam@nequeetnunc.com',
#   'streetaddress': 'Ap #944-5570 Nunc. Rd.',
#   'country': 'Pakistan',
#   'postalZip': '154758',
#   'address': {}},
#  {'type': 'customer',
#   'name': 'Jordan Strong',
#   'phone': '1-188-391-2011',
#   'email': 'tincidunt@quamcurabitur.net',
#   'streetaddress': 'Ap #426-2862 Lectus Rd.',
#   'country': 'United States',
#   'postalZip': '37144455',
#   'address': {}},
#  {'type': 'employee',
#   'name': 'Elton Mcpherson',
#   'phone': '1-733-172-5377',
#   'email': 'praesent@tempuseu.co.uk',
#   'streetaddress': '110-7294 Tempus Road',
#   'country': 'Belgium',
#   'postalZip': '89525',
#   'address': {}}]

# %% [markdown]
# #### Tehtävä 4. Muunna molemmat listat dataframeiksi ja yhdistä ne lopuksi yhdeksi dataframeksi (muista resetoida uuden dataframen indeksi!). Tulosta muodostetun dataframen sisältö.

# %%
C1_df = pd.DataFrame(C1)
#C1_df

# %%
C2_df = pd.DataFrame(C2)
#C2_df

# %%
henkilot = pd.concat([C1_df, C2_df])
henkilot.reset_index(inplace=True, drop=True)
henkilot
# Out:
#         type               name           phone  \
# 0   customer     Lawrence Burke  (815) 571-8746
# 1   employee      Angela Hinton  (997) 412-6965
# 2   customer    Whitney Flowers  1-573-471-9738
# 3   customer        Darius Burt  1-675-212-4934
# 4   customer      Solomon Blair            None
# 5   customer       Morgan Sykes  1-183-546-6564
# 6   employee       Zia Stafford  (621) 483-5714
# 7   employee     Cooper Ramirez  (716) 895-3353
# 8   customer  Richard Armstrong  (450) 317-2624
# 9   employee     Flavia Delaney            None
# 10  customer  Branden Henderson  1-314-584-1088
# 11  employee    Hector Kirkland  (325) 535-9750
# 12  customer        Luke Hooper            None
# 13  employee      Moses Dejesus  1-337-767-2455
# 14  customer          Finn Pena  1-746-189-1226
# 15  employee    Lester Espinoza  1-378-721-6318
# 16  employee     Nelle Stafford  1-246-844-4648
# 17  customer        Amber Casey            None
# 18  customer      Jordan Strong  1-188-391-2011
# 19  employee    Elton Mcpherson  1-733-172-5377
#
#                                            email  \
# 0              vulputate.lacus@elitfermentum.net
# 1                        elit.dictum@egestas.net
# 2   consectetuer.adipiscing.elit@ridiculusmus.ca
# 3                          sociis.natoque@ut.org
# 4             pede.suspendisse.dui@commodoat.edu
# 5               lorem.auctor@vulputatemauris.net
# 6                  ornare.fusce@felisdonec.co.uk
# 7     suspendisse@consectetueradipiscingelit.edu
# 8                        lacinia.mattis@urna.org
# 9                    rutrum.lorem.ac@inmagna.org
# 10                   iaculis@felisnullatempor.ca
# 11                            elit@orcilacus.org
# 12                 vitae.sodales@vitaesodales.ca
# 13                       pede@donecdignissim.org
# 14                           et.euismod.et@ac.ca
# 15                       vel.nisl.quisque@ad.org
# 16                            ligula@posuere.com
# 17                          diam@nequeetnunc.com
# 18                   tincidunt@quamcurabitur.net
# 19                       praesent@tempuseu.co.uk
#
#                         streetaddress             country    postalZip address
# 0           P.O. Box 478, 5254 Mi St.              Mexico        22044     NaN
# 1                   696-4409 Nunc Rd.             Germany       661217     NaN
# 2                        6978 Et, Av.           Indonesia        28164     NaN
# 3                      7705 Ut Street           Indonesia    94783-300     NaN
# 4        Ap #877-8946 Sociosqu Street             Germany       113513     NaN
# 5                     2594 Tellus St.  Russian Federation       584585      {}
# 6               Ap #419-5905 Nibh Rd.         Netherlands         7308      {}
# 7                 667-4582 Mollis Ave               India        43714      {}
# 8                Ap #120-495 Ut, Road  Russian Federation        53415      {}
# 9                    870-3073 Et, Av.             Austria        03247      {}
# 10  P.O. Box 961, 9477 Gravida Avenue            Pakistan        50217      {}
# 11             541-4061 Ultricies Ave      United Kingdom         3865      {}
# 12          Ap #385-5179 Luctus, Road             Germany         3660      {}
# 13         Ap #639-9807 Phasellus St.             Germany       903866      {}
# 14              Ap #668-4837 Nec Road         Netherlands        32910      {}
# 15                     4395 Elit, St.               Chile  07740-64584      {}
# 16          Ap #640-4104 Maecenas St.               Chile       800308      {}
# 17             Ap #944-5570 Nunc. Rd.            Pakistan       154758      {}
# 18            Ap #426-2862 Lectus Rd.       United States     37144455      {}
# 19               110-7294 Tempus Road             Belgium        89525      {}

# %% [markdown]
# #### Tehtävä 5. Osalla käyttäjistä puuttuu puhelinnumero. Ilmoita näiden käyttäjien lukumäärä.

# %%
einroa = henkilot['phone'].isna().sum()
einroa
# Out:
# 4
